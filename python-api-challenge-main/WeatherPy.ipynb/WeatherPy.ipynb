# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&appid="+weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | samfya
# Processing Record 3 of Set 1 | san antonio de pale
# Processing Record 4 of Set 1 | la ronge
# Processing Record 5 of Set 1 | papatowai
# Processing Record 6 of Set 1 | marang
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | arvayheer
# Processing Record 9 of Set 1 | invercargill
# Processing Record 10 of Set 1 | sonsorol village
# City not found. Skipping...
# Processing Record 11 of Set 1 | tutoia
# Processing Record 12 of Set 1 | al jubayl
# Processing Record 13 of Set 1 | susuman
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | varadero
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | keflavik
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | puerto natales
# Processing Record 21 of Set 1 | banda aceh
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | vorgashor
# Processing Record 24 of Set 1 | tibanbang
# Processing Record 25 of Set 1 | whakatane
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | margaret river
# Processing Record 29 of Set 1 | waitangi
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | colonia
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | xinmin
# Processing Record 34 of Set 1 | fort st. john
# Processing Record 35 of Set 1 | tallkayf
# Processing Record 36 of Set 1 | port mathurin
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | chimore
# Processing Record 41 of Set 1 | adamstown
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | remire-montjoly
# Processing Record 44 of Set 1 | ust-nera
# Processing Record 45 of Set 1 | qaqortoq
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | zaraza
# Processing Record 48 of Set 1 | soverato marina
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | rongelap
# Processing Record 0 of Set 2 | college
# Processing Record 1 of Set 2 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 2 of Set 2 | mitchell
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | poshekhon'ye
# Processing Record 5 of Set 2 | egilsstadir
# Processing Record 6 of Set 2 | kenai
# Processing Record 7 of Set 2 | misratah
# Processing Record 8 of Set 2 | stanley
# Processing Record 9 of Set 2 | ghanzi
# Processing Record 10 of Set 2 | potosi
# Processing Record 11 of Set 2 | puerto armuelles
# Processing Record 12 of Set 2 | novodvinsk
# Processing Record 13 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 2 | tolanaro
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | laikit, laikit ii (dimembe)
# Processing Record 19 of Set 2 | west island
# Processing Record 20 of Set 2 | ribeira brava
# Processing Record 21 of Set 2 | praia da vitoria
# Processing Record 22 of Set 2 | polyarnyy
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | mount gambier
# Processing Record 25 of Set 2 | kiruna
# Processing Record 26 of Set 2 | chinde
# Processing Record 27 of Set 2 | atar
# Processing Record 28 of Set 2 | saint-pierre
# Processing Record 29 of Set 2 | geiro
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | sungai penuh
# Processing Record 32 of Set 2 | port lincoln
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 36 of Set 2 | dalandzadgad
# Processing Record 37 of Set 2 | junin de los andes
# Processing Record 38 of Set 2 | gisborne
# Processing Record 39 of Set 2 | polva
# Processing Record 40 of Set 2 | badger
# Processing Record 41 of Set 2 | grants pass
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | zeya
# Processing Record 44 of Set 2 | alice springs
# Processing Record 45 of Set 2 | nabire
# Processing Record 46 of Set 2 | estacion huehuetan
# City not found. Skipping...
# Processing Record 47 of Set 2 | anshun
# Processing Record 48 of Set 2 | aasiaat
# Processing Record 49 of Set 2 | kavieng
# Processing Record 0 of Set 3 | villa de cos
# Processing Record 1 of Set 3 | shihezi
# Processing Record 2 of Set 3 | tazacorte
# Processing Record 3 of Set 3 | luau
# Processing Record 4 of Set 3 | zhigalovo
# Processing Record 5 of Set 3 | happy valley-goose bay
# Processing Record 6 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | mejit
# Processing Record 10 of Set 3 | marsa alam
# Processing Record 11 of Set 3 | sona
# Processing Record 12 of Set 3 | cayambe
# Processing Record 13 of Set 3 | yeppoon
# Processing Record 14 of Set 3 | n'zeto
# Processing Record 15 of Set 3 | pandan
# Processing Record 16 of Set 3 | ancud
# Processing Record 17 of Set 3 | amta
# Processing Record 18 of Set 3 | afaahiti
# Processing Record 19 of Set 3 | utrik
# Processing Record 20 of Set 3 | mazabuka
# Processing Record 21 of Set 3 | gadzhiyevo
# Processing Record 22 of Set 3 | hafar al-batin
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | shiyan
# Processing Record 25 of Set 3 | california
# Processing Record 26 of Set 3 | kibondo
# Processing Record 27 of Set 3 | olonkinbyen
# Processing Record 28 of Set 3 | conduaga
# Processing Record 29 of Set 3 | el porvenir
# Processing Record 30 of Set 3 | cheremukhovo
# Processing Record 31 of Set 3 | udachny
# Processing Record 32 of Set 3 | rio grande
# Processing Record 33 of Set 3 | vilyuysk
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | nieuw amsterdam
# Processing Record 36 of Set 3 | ta`u
# Processing Record 37 of Set 3 | dryden
# Processing Record 38 of Set 3 | victoria falls
# Processing Record 39 of Set 3 | whitehorse
# Processing Record 40 of Set 3 | balkanabat
# Processing Record 41 of Set 3 | prieska
# Processing Record 42 of Set 3 | iskateley
# Processing Record 43 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | lucheng
# Processing Record 46 of Set 3 | kuusamo
# Processing Record 47 of Set 3 | haiku-pauwela
# Processing Record 48 of Set 3 | qarazhal
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 0 of Set 4 | shar
# Processing Record 1 of Set 4 | flagstaff
# Processing Record 2 of Set 4 | cabo san lucas
# Processing Record 3 of Set 4 | wailua homesteads
# Processing Record 4 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 5 of Set 4 | constantia
# Processing Record 6 of Set 4 | thunder bay
# Processing Record 7 of Set 4 | isafjordur
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | severo-yeniseyskiy
# Processing Record 10 of Set 4 | lakeview
# Processing Record 11 of Set 4 | chililabombwe
# Processing Record 12 of Set 4 | seogwipo
# City not found. Skipping...
# Processing Record 13 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 14 of Set 4 | fuling
# Processing Record 15 of Set 4 | dudinka
# Processing Record 16 of Set 4 | crane
# Processing Record 17 of Set 4 | vuktyl
# Processing Record 18 of Set 4 | saipan
# Processing Record 19 of Set 4 | el granada
# Processing Record 20 of Set 4 | lihue
# Processing Record 21 of Set 4 | okha
# Processing Record 22 of Set 4 | batken
# Processing Record 23 of Set 4 | klyuchi
# Processing Record 24 of Set 4 | urucara
# Processing Record 25 of Set 4 | nema
# Processing Record 26 of Set 4 | kingston
# Processing Record 27 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 28 of Set 4 | nemuro
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | atafu village
# Processing Record 31 of Set 4 | queenstown
# Processing Record 32 of Set 4 | antigonish
# Processing Record 33 of Set 4 | hagere selam
# Processing Record 34 of Set 4 | nadym
# Processing Record 35 of Set 4 | taroa
# Processing Record 36 of Set 4 | nar'yan-mar
# Processing Record 37 of Set 4 | abepura
# Processing Record 38 of Set 4 | vilyuchinsk
# Processing Record 39 of Set 4 | waingapu
# Processing Record 40 of Set 4 | charters towers
# Processing Record 41 of Set 4 | weno
# Processing Record 42 of Set 4 | bilecik
# Processing Record 43 of Set 4 | pakxan
# Processing Record 44 of Set 4 | uturoa
# Processing Record 45 of Set 4 | kourou
# Processing Record 46 of Set 4 | creel
# Processing Record 47 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 48 of Set 4 | broceni
# Processing Record 49 of Set 4 | xiulin
# Processing Record 0 of Set 5 | lebu
# Processing Record 1 of Set 5 | motueka
# Processing Record 2 of Set 5 | ebon
# Processing Record 3 of Set 5 | quellon
# Processing Record 4 of Set 5 | calvinia
# Processing Record 5 of Set 5 | tangalle
# Processing Record 6 of Set 5 | rio gallegos
# Processing Record 7 of Set 5 | sodra sandby
# Processing Record 8 of Set 5 | magadan
# Processing Record 9 of Set 5 | paramonga
# Processing Record 10 of Set 5 | al manzalah
# Processing Record 11 of Set 5 | lagunas
# Processing Record 12 of Set 5 | usinsk
# Processing Record 13 of Set 5 | lensk
# Processing Record 14 of Set 5 | uige
# Processing Record 15 of Set 5 | tsaratanana
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | meadow lake
# Processing Record 18 of Set 5 | malaya vishera
# Processing Record 19 of Set 5 | hadibu
# Processing Record 20 of Set 5 | namsos
# Processing Record 21 of Set 5 | el kala
# Processing Record 22 of Set 5 | krasnogorskoye
# Processing Record 23 of Set 5 | nizhnyaya tavda
# Processing Record 24 of Set 5 | sittwe
# Processing Record 25 of Set 5 | carauari
# Processing Record 26 of Set 5 | gulf shores
# Processing Record 27 of Set 5 | labasa
# Processing Record 28 of Set 5 | nantucket
# Processing Record 29 of Set 5 | kittila
# Processing Record 30 of Set 5 | ouro preto do oeste
# Processing Record 31 of Set 5 | el calafate
# Processing Record 32 of Set 5 | mainhardt
# Processing Record 33 of Set 5 | zavitinsk
# Processing Record 34 of Set 5 | mersing
# Processing Record 35 of Set 5 | donskoy
# Processing Record 36 of Set 5 | hammerfest
# Processing Record 37 of Set 5 | ruidoso
# Processing Record 38 of Set 5 | luanda
# Processing Record 39 of Set 5 | usogorsk
# Processing Record 40 of Set 5 | st. john's
# Processing Record 41 of Set 5 | leava
# Processing Record 42 of Set 5 | velyka dymerka
# Processing Record 43 of Set 5 | beni saf
# Processing Record 44 of Set 5 | freetown
# Processing Record 45 of Set 5 | santa rosa del sara
# Processing Record 46 of Set 5 | rikaze
# Processing Record 47 of Set 5 | nuuk
# Processing Record 48 of Set 5 | turbat
# Processing Record 49 of Set 5 | flin flon
# Processing Record 0 of Set 6 | marsabit
# Processing Record 1 of Set 6 | roxas
# Processing Record 2 of Set 6 | kimbe
# Processing Record 3 of Set 6 | kingscliff
# Processing Record 4 of Set 6 | mar del plata
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | kruisfontein
# Processing Record 7 of Set 6 | kavaratti
# Processing Record 8 of Set 6 | taco pozo
# Processing Record 9 of Set 6 | khandyga
# Processing Record 10 of Set 6 | alamo
# Processing Record 11 of Set 6 | tsiombe
# Processing Record 12 of Set 6 | laojunmiao
# Processing Record 13 of Set 6 | howard springs
# Processing Record 14 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 6 | weener
# Processing Record 16 of Set 6 | northam
# Processing Record 17 of Set 6 | popondetta
# Processing Record 18 of Set 6 | uyuni
# Processing Record 19 of Set 6 | bejubang dua
# City not found. Skipping...
# Processing Record 20 of Set 6 | chenaran
# Processing Record 21 of Set 6 | islamorada
# Processing Record 22 of Set 6 | tual
# Processing Record 23 of Set 6 | faya-largeau
# Processing Record 24 of Set 6 | balykshi
# Processing Record 25 of Set 6 | hawaiian paradise park
# Processing Record 26 of Set 6 | ust'-ilimsk
# Processing Record 27 of Set 6 | peterhead
# Processing Record 28 of Set 6 | namtsy
# Processing Record 29 of Set 6 | nuku'alofa
# Processing Record 30 of Set 6 | dunedin
# Processing Record 31 of Set 6 | tawau
# Processing Record 32 of Set 6 | lazaro cardenas
# Processing Record 33 of Set 6 | yulinshi
# Processing Record 34 of Set 6 | jinchang
# Processing Record 35 of Set 6 | tadmur
# Processing Record 36 of Set 6 | saint-philippe
# Processing Record 37 of Set 6 | esmeralda
# Processing Record 38 of Set 6 | minbu
# Processing Record 39 of Set 6 | damavand
# Processing Record 40 of Set 6 | zaigrayevo
# Processing Record 41 of Set 6 | gwaram
# Processing Record 42 of Set 6 | warren
# Processing Record 43 of Set 6 | kralendijk
# Processing Record 44 of Set 6 | morehead city
# Processing Record 45 of Set 6 | kabo
# Processing Record 46 of Set 6 | labuan
# Processing Record 47 of Set 6 | lubang
# Processing Record 48 of Set 6 | eastham
# Processing Record 49 of Set 6 | buturlino
# Processing Record 0 of Set 7 | port alfred
# Processing Record 1 of Set 7 | novoleushkovskaya
# Processing Record 2 of Set 7 | nadi
# Processing Record 3 of Set 7 | jurm
# Processing Record 4 of Set 7 | vadso
# Processing Record 5 of Set 7 | murray bridge
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | tezu
# Processing Record 8 of Set 7 | yuzhno-kurilsk
# Processing Record 9 of Set 7 | presidente medici
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | cobija
# Processing Record 12 of Set 7 | la passe
# Processing Record 13 of Set 7 | buga
# Processing Record 14 of Set 7 | talcahuano
# Processing Record 15 of Set 7 | thongwa
# Processing Record 16 of Set 7 | watampone
# Processing Record 17 of Set 7 | yelan'-koleno
# Processing Record 18 of Set 7 | ashland
# Processing Record 19 of Set 7 | abraham's bay
# City not found. Skipping...
# Processing Record 20 of Set 7 | walvis bay
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | youghal
# Processing Record 23 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 24 of Set 7 | annau
# Processing Record 25 of Set 7 | castillos
# Processing Record 26 of Set 7 | bikenibeu village
# Processing Record 27 of Set 7 | tazovsky
# Processing Record 28 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 29 of Set 7 | oravita
# Processing Record 30 of Set 7 | shendi
# Processing Record 31 of Set 7 | arendal
# Processing Record 32 of Set 7 | revda
# Processing Record 33 of Set 7 | plastun
# Processing Record 34 of Set 7 | enewetak
# Processing Record 35 of Set 7 | al jawf
# Processing Record 36 of Set 7 | karwar
# Processing Record 37 of Set 7 | kiama
# Processing Record 38 of Set 7 | madison
# Processing Record 39 of Set 7 | astrakhan
# Processing Record 40 of Set 7 | khabary
# Processing Record 41 of Set 7 | calama
# Processing Record 42 of Set 7 | rio guayabal de yateras
# Processing Record 43 of Set 7 | char bhadrasan
# Processing Record 44 of Set 7 | gubkin
# Processing Record 45 of Set 7 | nizhniy kuranakh
# Processing Record 46 of Set 7 | woolgoolga
# Processing Record 47 of Set 7 | kolwezi
# Processing Record 48 of Set 7 | nizhneangarsk
# Processing Record 49 of Set 7 | ternate
# Processing Record 0 of Set 8 | kathmandu
# Processing Record 1 of Set 8 | baker city
# Processing Record 2 of Set 8 | bamboo flat
# Processing Record 3 of Set 8 | punta del este
# Processing Record 4 of Set 8 | lodeynoye pole
# Processing Record 5 of Set 8 | kayes
# Processing Record 6 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 8 | lugu
# Processing Record 8 of Set 8 | chadron
# Processing Record 9 of Set 8 | tofol
# Processing Record 10 of Set 8 | saratamata
# City not found. Skipping...
# Processing Record 11 of Set 8 | pisco
# Processing Record 12 of Set 8 | timimoun
# Processing Record 13 of Set 8 | novo cruzeiro
# Processing Record 14 of Set 8 | lautoka
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | lionel town
# Processing Record 17 of Set 8 | agat village
# Processing Record 18 of Set 8 | nova sintra
# Processing Record 19 of Set 8 | tekirdag
# Processing Record 20 of Set 8 | okhotsk
# Processing Record 21 of Set 8 | bargara
# City not found. Skipping...
# Processing Record 22 of Set 8 | vila velha
# Processing Record 23 of Set 8 | kaa-khem
# Processing Record 24 of Set 8 | vorkuta
# Processing Record 25 of Set 8 | bakchar
# Processing Record 26 of Set 8 | tidjikja
# Processing Record 27 of Set 8 | quelimane
# Processing Record 28 of Set 8 | neryungri
# Processing Record 29 of Set 8 | port shepstone
# Processing Record 30 of Set 8 | karratha
# Processing Record 31 of Set 8 | monywa
# Processing Record 32 of Set 8 | souillac
# Processing Record 33 of Set 8 | pangody
# Processing Record 34 of Set 8 | al 'alamayn
# City not found. Skipping...
# Processing Record 35 of Set 8 | skerries
# Processing Record 36 of Set 8 | manta
# Processing Record 37 of Set 8 | cadale
# Processing Record 38 of Set 8 | shohimardon
# Processing Record 39 of Set 8 | dolores
# Processing Record 40 of Set 8 | gaiman
# Processing Record 41 of Set 8 | shahdad kot
# Processing Record 42 of Set 8 | chasong
# Processing Record 43 of Set 8 | flying fish cove
# Processing Record 44 of Set 8 | squamish
# Processing Record 45 of Set 8 | loikaw
# Processing Record 46 of Set 8 | okulovka
# Processing Record 47 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 48 of Set 8 | juneau
# Processing Record 49 of Set 8 | mugia
# Processing Record 0 of Set 9 | kolonia
# Processing Record 1 of Set 9 | howick
# Processing Record 2 of Set 9 | nehe
# Processing Record 3 of Set 9 | malango
# Processing Record 4 of Set 9 | lerwick
# Processing Record 5 of Set 9 | kerikeri
# Processing Record 6 of Set 9 | erenhot
# Processing Record 7 of Set 9 | salalah
# Processing Record 8 of Set 9 | prince rupert
# Processing Record 9 of Set 9 | la foa
# Processing Record 10 of Set 9 | ormara
# Processing Record 11 of Set 9 | torbat-e jam
# Processing Record 12 of Set 9 | lata
# Processing Record 13 of Set 9 | la sarre
# Processing Record 14 of Set 9 | piti village
# Processing Record 15 of Set 9 | harstad
# Processing Record 16 of Set 9 | sompeta
# Processing Record 17 of Set 9 | tomohon
# Processing Record 18 of Set 9 | richfield
# Processing Record 19 of Set 9 | ingeniero luis a. huergo
# Processing Record 20 of Set 9 | siwa oasis
# Processing Record 21 of Set 9 | aykhal
# Processing Record 22 of Set 9 | nova vicosa
# Processing Record 23 of Set 9 | bireun
# Processing Record 24 of Set 9 | antalaha
# Processing Record 25 of Set 9 | prabumulih
# Processing Record 26 of Set 9 | kununurra
# Processing Record 27 of Set 9 | libertad
# Processing Record 28 of Set 9 | boyalik
# Processing Record 29 of Set 9 | bereket
# Processing Record 30 of Set 9 | nouadhibou
# Processing Record 31 of Set 9 | amga
# Processing Record 32 of Set 9 | dalnegorsk
# Processing Record 33 of Set 9 | sur
# Processing Record 34 of Set 9 | jalqani
# Processing Record 35 of Set 9 | tsagan aman
# Processing Record 36 of Set 9 | ovalle
# Processing Record 37 of Set 9 | lodwar
# Processing Record 38 of Set 9 | toliara
# Processing Record 39 of Set 9 | ixtapa
# Processing Record 40 of Set 9 | bafata
# Processing Record 41 of Set 9 | kapit
# Processing Record 42 of Set 9 | margate
# Processing Record 43 of Set 9 | pico truncado
# Processing Record 44 of Set 9 | kuna
# Processing Record 45 of Set 9 | inirida
# Processing Record 46 of Set 9 | al abyar
# Processing Record 47 of Set 9 | mournies
# Processing Record 48 of Set 9 | louisville
# Processing Record 49 of Set 9 | gardnerville ranchos
# Processing Record 0 of Set 10 | lockwood
# Processing Record 1 of Set 10 | bridgewater
# Processing Record 2 of Set 10 | chonchi
# Processing Record 3 of Set 10 | al kharijah
# Processing Record 4 of Set 10 | xilin hot
# Processing Record 5 of Set 10 | epanomi
# Processing Record 6 of Set 10 | turabah
# Processing Record 7 of Set 10 | port douglas
# Processing Record 8 of Set 10 | la'ie
# Processing Record 9 of Set 10 | ban nong wua so
# Processing Record 10 of Set 10 | maumere
# Processing Record 11 of Set 10 | sisimiut
# Processing Record 12 of Set 10 | quang ngai
# Processing Record 13 of Set 10 | antonio enes
# Processing Record 14 of Set 10 | fale old settlement
# Processing Record 15 of Set 10 | kyabe
# Processing Record 16 of Set 10 | dubrovnik
# Processing Record 17 of Set 10 | sumbe
# Processing Record 18 of Set 10 | qasr-e qand
# City not found. Skipping...
# Processing Record 19 of Set 10 | luderitz
# Processing Record 20 of Set 10 | limache
# Processing Record 21 of Set 10 | praia
# Processing Record 22 of Set 10 | oodweyne
# Processing Record 23 of Set 10 | smithers
# Processing Record 24 of Set 10 | carutapera
# Processing Record 25 of Set 10 | north battleford
# Processing Record 26 of Set 10 | palmerston north
# Processing Record 27 of Set 10 | taoudenni
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | mouila
# Processing Record 30 of Set 10 | inhambane
# Processing Record 31 of Set 10 | mukalla
# Processing Record 32 of Set 10 | kiamba
# Processing Record 33 of Set 10 | saudarkrokur
# Processing Record 34 of Set 10 | al miqdadiyah
# Processing Record 35 of Set 10 | santa cruz
# Processing Record 36 of Set 10 | surskoye
# Processing Record 37 of Set 10 | kapuskasing
# Processing Record 38 of Set 10 | piacabucu
# Processing Record 39 of Set 10 | minas de marcona
# Processing Record 40 of Set 10 | maubara
# City not found. Skipping...
# Processing Record 41 of Set 10 | palu
# Processing Record 42 of Set 10 | winnemucca
# Processing Record 43 of Set 10 | hasaki
# Processing Record 44 of Set 10 | kiunga
# Processing Record 45 of Set 10 | prado
# Processing Record 46 of Set 10 | dinard
# Processing Record 47 of Set 10 | rio preto da eva
# Processing Record 48 of Set 10 | gopalganj
# Processing Record 49 of Set 10 | san luis de la loma
# Processing Record 0 of Set 11 | chicxulub puerto
# City not found. Skipping...
# Processing Record 1 of Set 11 | port blair
# Processing Record 2 of Set 11 | sonqor
# Processing Record 3 of Set 11 | kristiansund
# Processing Record 4 of Set 11 | cockburn town
# Processing Record 5 of Set 11 | patti
# Processing Record 6 of Set 11 | terbuny
# Processing Record 7 of Set 11 | wittingen
# Processing Record 8 of Set 11 | cuatro cienegas de carranza
# Processing Record 9 of Set 11 | suva
# Processing Record 10 of Set 11 | bel ombre
# Processing Record 11 of Set 11 | san patricio
# Processing Record 12 of Set 11 | barika
# Processing Record 13 of Set 11 | vernon
# Processing Record 14 of Set 11 | oulunsalo
# Processing Record 15 of Set 11 | gorontalo
# Processing Record 16 of Set 11 | olinda
# Processing Record 17 of Set 11 | zouerate
# Processing Record 18 of Set 11 | mossel bay
# Processing Record 19 of Set 11 | san jorge
# Processing Record 20 of Set 11 | port saint john's
# Processing Record 21 of Set 11 | moyale
# Processing Record 22 of Set 11 | broken hill
# Processing Record 23 of Set 11 | urzhar
# Processing Record 24 of Set 11 | coquimbo
# Processing Record 25 of Set 11 | sant'ambrogio di valpollicella
# Processing Record 26 of Set 11 | merizo village
# Processing Record 27 of Set 11 | montrose
# Processing Record 28 of Set 11 | alotau
# Processing Record 29 of Set 11 | borger
# Processing Record 30 of Set 11 | sarmiento
# Processing Record 31 of Set 11 | tommot
# Processing Record 32 of Set 11 | santa elena de uairen
# Processing Record 33 of Set 11 | sao gabriel da cachoeira
# Processing Record 34 of Set 11 | motril
# Processing Record 35 of Set 11 | levuka
# Processing Record 36 of Set 11 | argo
# Processing Record 37 of Set 11 | trairi
# Processing Record 38 of Set 11 | kuanda
# Processing Record 39 of Set 11 | alappakkam
# Processing Record 40 of Set 11 | east london
# Processing Record 41 of Set 11 | tvoroyri
# Processing Record 42 of Set 11 | gargzdai
# Processing Record 43 of Set 11 | chengde
# Processing Record 44 of Set 11 | ataq
# Processing Record 45 of Set 11 | eagle point
# Processing Record 46 of Set 11 | launceston
# Processing Record 47 of Set 11 | ust'-kulom
# Processing Record 48 of Set 11 | fort bragg
# Processing Record 49 of Set 11 | mount isa
# Processing Record 0 of Set 12 | iringa
# Processing Record 1 of Set 12 | alamosa
# Processing Record 2 of Set 12 | las vegas
# Processing Record 3 of Set 12 | chebba
# Processing Record 4 of Set 12 | karasburg
# Processing Record 5 of Set 12 | celestun
# Processing Record 6 of Set 12 | peace river
# Processing Record 7 of Set 12 | muynoq
# Processing Record 8 of Set 12 | smirnykh
# Processing Record 9 of Set 12 | jining
# Processing Record 10 of Set 12 | qingnian
# Processing Record 11 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 12 | sao vicente
# Processing Record 13 of Set 12 | acarau
# Processing Record 14 of Set 12 | aras-asan
# Processing Record 15 of Set 12 | kampong thom
# Processing Record 16 of Set 12 | mandalgovi
# Processing Record 17 of Set 12 | thinadhoo
# Processing Record 18 of Set 12 | ponta delgada
# Processing Record 19 of Set 12 | brezina
# Processing Record 20 of Set 12 | chibougamau
# Processing Record 21 of Set 12 | alofi
# Processing Record 22 of Set 12 | dmitrovsk-orlovskiy
# Processing Record 23 of Set 12 | al ghayzah
# Processing Record 24 of Set 12 | touros
# Processing Record 25 of Set 12 | mbandaka
# Processing Record 26 of Set 12 | jiuquan
# Processing Record 27 of Set 12 | madugula
# Processing Record 28 of Set 12 | camacupa
# Processing Record 29 of Set 12 | laramie
# Processing Record 30 of Set 12 | rumphi
# Processing Record 31 of Set 12 | andergrove
# Processing Record 32 of Set 12 | xiaoweizhai
# Processing Record 33 of Set 12 | kuqa
# Processing Record 34 of Set 12 | nelson bay
# Processing Record 35 of Set 12 | lebyazh'ye
# Processing Record 36 of Set 12 | tukrah
# Processing Record 37 of Set 12 | timmins
# Processing Record 38 of Set 12 | monteagudo
# Processing Record 39 of Set 12 | tralee
# Processing Record 40 of Set 12 | maisi
# Processing Record 41 of Set 12 | phu kradueng
# Processing Record 42 of Set 12 | laguna
# Processing Record 43 of Set 12 | boa vista
# Processing Record 44 of Set 12 | midvagur
# Processing Record 45 of Set 12 | salinopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676  -12.3116     14.17        83
# 1                       samfya -11.3649   29.5565     20.97        26
# 2          san antonio de pale  -1.4014    5.6325     22.99        85
# 3                     la ronge  55.1001 -105.2842     21.14        56
# 4                    papatowai -46.5619  169.4708      8.38        72
#
#    Cloudiness  Wind Speed Country        Date
# 0          95       17.03      SH  1721759316
# 1           0        4.94      ZM  1721759317
# 2          44        4.61      GQ  1721759319
# 3          40        7.72      CA  1721759320
# 4          62        4.44      NZ  1721759321

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116     14.17        83
# 1                             samfya -11.3649   29.5565     20.97        26
# 2                san antonio de pale  -1.4014    5.6325     22.99        85
# 3                           la ronge  55.1001 -105.2842     21.14        56
# 4                          papatowai -46.5619  169.4708      8.38        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                95       17.03      SH  1721759316
# 1                 0        4.94      ZM  1721759317
# 2                44        4.61      GQ  1721759319
# 3                40        7.72      CA  1721759320
# 4                62        4.44      NZ  1721759321

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2024-06-17)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2024-06-17)")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2024-06-17)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2024-06-17)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regression_plot(xvalues, yvalues):
    (slope,intercept,rvalue,pvalue,stderr) = linregress(xvalues,yvalues)
    
    regression_values = xvalues* slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3         la ronge  55.1001 -105.2842     21.14        56          40
# 5           marang   5.2056  103.2059     27.95        88          95
# 7        arvayheer  46.2639  102.7750     12.80        77          92
# 10       al jubayl  27.0112   49.6583     35.22        43          22
# 11         susuman  62.7833  148.1667     16.54        78         100
#
#          Wind Speed Country        Date
# City_ID
# 3              7.72      CA  1721759320
# 5              1.01      MY  1721759322
# 7              3.61      MN  1721759325
# 10             1.30      SA  1721759329
# 11             0.78      RU  1721759330

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116     14.17        83
# 1                             samfya -11.3649   29.5565     20.97        26
# 2                san antonio de pale  -1.4014    5.6325     22.99        85
# 4                          papatowai -46.5619  169.4708      8.38        72
# 6                  port-aux-francais -49.3500   70.2167      1.18        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                95       17.03      SH  1721759316
# 1                 0        4.94      ZM  1721759317
# 2                44        4.61      GQ  1721759319
# 4                62        4.44      NZ  1721759321
# 6               100       13.48      TF  1721759323

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Max Temp")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:-0.6466242945826364

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Max Temp")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:0.7418047881789309

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere has a negative liner regression when it comes to
# Max Tempature while the Southern Hemisphere has a positive liner regression.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:0.006082975159153374

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:0.004703823323147368

# %% [markdown]
# **Discussion about the linear relationship:** Both the Northern Hemisphere and the Sothern Hemisphere have a slight positive liner regression when it comes to Humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:-0.06795324900119629

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:-0.06489571367638462

# %% [markdown]
# **Discussion about the linear relationship:** Both the Northern Hemisphere and the Southern Hemisphere have a negative liner regression when it comes to cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:-0.08202015871311655

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title("Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f'The r^2-value is:{rvalue}')

plt.show()
# Out:
# The r^2-value is:-0.30553678816073165

# %% [markdown]
# **Discussion about the linear relationship:** Both the Northern Hemisphere and the Southern Hemisphere have a negative liner regression when it comes to wind speed.
